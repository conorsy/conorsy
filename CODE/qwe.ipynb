# %%
import numpy as np
import xarray as xr
import matplotlib.pyplot as plt

# %% [markdown]
# NOAA Climate Data Record (CDR) of AVHRR Normalized Difference Vegetation Index (NDVI), Version 5
#
# https://www.ncei.noaa.gov/metadata/geoportal/rest/metadata/item/gov.noaa.ncdc:C01558/html

# %%
NDVI = xr.open_dataset("../DATA/2024_VIIRS-Land_v001_JP113C1_NOAA-20_20240801_c20240803143011.nc", decode_times=False)

# %%
NDVI
# Out:
# <xarray.Dataset> Size: 1MB
# Dimensions:    (time: 1, latitude: 201, longitude: 301, ncrs: 1)
# Coordinates:
#   * time       (time) float32 4B 1.592e+04
#   * latitude   (latitude) float32 804B 59.97 59.92 59.88 ... 50.07 50.02 49.97
#   * longitude  (longitude) float32 1kB -14.98 -14.93 -14.88 ... -0.02501 0.02499
# Dimensions without coordinates: ncrs
# Data variables:
#     NDVI       (time, latitude, longitude) float64 484kB ...
#     crs        (ncrs) int16 2B ...
#     QA         (time, latitude, longitude) int16 121kB ...
#     TIMEOFDAY  (time, latitude, longitude) int64 484kB ...
# Attributes: (12/45)
#     title:                             Normalized Difference Vegetation Index...
#     institution:                       NASA/GSFC/SED/ESD/HBSL/TIS/MODIS-LAND ...
#     Conventions:                       CF-1.6, ACDD-1.3
#     standard_name_vocabulary:          CF Standard Name Table (v25, 05 July 2...
#     naming_authority:                  gov.noaa.ncei
# ...

# %%
NDVI['NDVI'].isel(time=0).plot.imshow(cmap='viridis')

# %%
NDVI['NDVI'][0,:].min().values
# Out:
# array(-0.0323)

# %%
NDVI['NDVI'][0,:].max().values
# Out:
# array(0.977)

# %%
NDVI['QA'].isel(time=0).plot.imshow(cmap='viridis')
